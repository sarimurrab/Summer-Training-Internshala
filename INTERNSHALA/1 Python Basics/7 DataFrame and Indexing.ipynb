# %%
import pandas as pd

# %%
a= pd.read_csv("data.csv")

# %%
a.shape
# Out:
# (891, 12)

# %%
a.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
a.tail(4)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# # access all comumns

# %%
a.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# # specific one column

# %%
a['Fare'].head(3)
# Out:
# 0     7.2500
# 1    71.2833
# 2     7.9250
# Name: Fare, dtype: float64

# %% [markdown]
# # specific more than one or a list of column

# %%
a[["Fare",'Cabin','Parch']].head(6)
# Out:
#       Fare Cabin  Parch
# 0   7.2500   NaN      0
# 1  71.2833   C85      0
# 2   7.9250   NaN      0
# 3  53.1000  C123      0
# 4   8.0500   NaN      0
# 5   8.4583   NaN      0

# %% [markdown]
# # #selcting column and rows using iloc[] function
# ## iloc[ 1:3(rows) ,  3:4(column)]

# %%
a.iloc[:3]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
a.iloc[1:4, 4:7]
# Out:
#       Sex   Age  SibSp
# 1  female  38.0      1
# 2  female  26.0      0
# 3  female  35.0      1

# %% [markdown]
# # selecting row where column value is equal to :

# %%
a[a['Parch']==1]
# Out:
#      PassengerId  Survived  Pclass  \
# 7              8         0       3
# 10            11         1       3
# 16            17         0       3
# 24            25         0       3
# 50            51         0       3
# 54            55         0       1
# 65            66         1       3
# 97            98         1       1
# 98            99         1       2
# 102          103         0       1
# 118          119         0       1
# 124          125         0       1
# 128          129         1       3
# 145          146         0       2
# 155          156         0       1
# 160          161         0       3
# 164          165         0       3
# 166          167         1       1
# 171          172         0       3
# 172          173         1       3
# 175          176         0       3
# 176          177         0       3
# 183          184         1       2
# 188          189         0       3
# 193          194         1       2
# ...

# %%
a[a['Sex']=='female']
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 14            15         0       3
# 15            16         1       2
# 18            19         0       3
# 19            20         1       3
# 22            23         1       3
# 24            25         0       3
# 25            26         1       3
# 28            29         1       3
# 31            32         1       1
# 32            33         1       3
# 38            39         0       3
# 39            40         1       3
# 40            41         0       3
# 41            42         0       2
# 43            44         1       2
# 44            45         1       3
# 47            48         1       3
# 49            50         0       3
# ...
